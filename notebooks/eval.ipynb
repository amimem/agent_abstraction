# %%
import pandas as pd

# %%
# load datafram from pickle
df = pd.read_pickle('./data/PPOTrainer_simple_tag_2022-10-23_03-46-14i9w23pv7/checkpoint_000001_data.pkl')

# %%
df.head()

# %%
df[df["eval_episode"] == 0]

# %%
df[df["eval_episode"] == 9]
